# %% [markdown]
# # 제품 이상여부 판별 프로젝트

# %% [markdown]
# ## 1. 데이터 불러오기

# %% [markdown]
# ### 필수 라이브러리

# %%
import os
from pprint import pprint

import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %% [markdown]
# ### 데이터 읽어오기

# %%
ROOT_DIR = "data"
RANDOM_STATE = 110

# Load data
train_data = pd.read_csv(os.path.join(ROOT_DIR, "train.csv"))
train_data
# Out:
#       Wip Line_Dam Process Desc._Dam     Equipment_Dam Model.Suffix_Dam  \
# 0          IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334505
# 1          IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334505
# 2          IVI-OB6     Dam Dispenser  Dam dispenser #2      AJX75334501
# 3          IVI-OB6     Dam Dispenser  Dam dispenser #2      AJX75334501
# 4          IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334501
# ...            ...               ...               ...              ...
# 40501      IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334501
# 40502      IVI-OB6     Dam Dispenser  Dam dispenser #2      AJX75334501
# 40503      IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334501
# 40504      IVI-OB6     Dam Dispenser  Dam dispenser #2      AJX75334501
# 40505      IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334501
#
#       Workorder_Dam  Insp. Seq No._Dam Insp Judge Code_Dam  \
# 0        4F1XA938-1                  1                  OK
# 1        3KPM0016-2                  1                  OK
# 2        4E1X9167-1                  1                  OK
# 3        3K1X0057-1                  1                  OK
# 4        3HPM0007-1                  1                  OK
# ...             ...                ...                 ...
# 40501    3J1XF434-2                  1                  OK
# 40502    4E1XC796-1                  1                  OK
# 40503    4C1XD438-1                  1                  OK
# 40504    3I1XA258-1                  1                  OK
# 40505    3G1XA501-1                  1                  OK
#
#        CURE END POSITION X Collect Result_Dam  \
# 0                                       240.0
# 1                                       240.0
# 2                                      1000.0
# 3                                      1000.0
# 4                                       240.0
# ...                                       ...
# 40501                                   240.0
# 40502                                  1000.0
# 40503                                   240.0
# 40504                                  1000.0
# 40505                                   240.0
#
#        CURE END POSITION X Unit Time_Dam  CURE END POSITION X Judge Value_Dam  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# ...                                  ...                                  ...
# 40501                                NaN                                  NaN
# 40502                                NaN                                  NaN
# 40503                                NaN                                  NaN
# 40504                                NaN                                  NaN
# 40505                                NaN                                  NaN
#
#        ...  Production Qty Collect Result_Fill2  \
# 0      ...                                    7
# 1      ...                                  185
# 2      ...                                   10
# 3      ...                                  268
# 4      ...                                  121
# ...    ...                                  ...
# 40501  ...                                  318
# 40502  ...                                   14
# 40503  ...                                    1
# 40504  ...                                  117
# 40505  ...                                  320
#
#        Production Qty Unit Time_Fill2  Production Qty Judge Value_Fill2  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
# ...                               ...                               ...
# 40501                             NaN                               NaN
# 40502                             NaN                               NaN
# 40503                             NaN                               NaN
# 40504                             NaN                               NaN
# 40505                             NaN                               NaN
#
#        Receip No Collect Result_Fill2  Receip No Unit Time_Fill2  \
# 0                                 127                        NaN
# 1                                   1                        NaN
# 2                                  73                        NaN
# 3                                   1                        NaN
# 4                                   1                        NaN
# ...                               ...                        ...
# 40501                               1                        NaN
# 40502                             197                        NaN
# 40503                              27                        NaN
# 40504                               1                        NaN
# 40505                               1                        NaN
#
#        Receip No Judge Value_Fill2  WorkMode Collect Result_Fill2  \
# 0                              NaN                              1
# 1                              NaN                              0
# 2                              NaN                              1
# 3                              NaN                              0
# 4                              NaN                              0
# ...                            ...                            ...
# 40501                          NaN                              0
# 40502                          NaN                              1
# 40503                          NaN                              1
# 40504                          NaN                              0
# 40505                          NaN                              0
#
#        WorkMode Unit Time_Fill2  WorkMode Judge Value_Fill2    target
# 0                           NaN                         NaN    Normal
# 1                           NaN                         NaN    Normal
# 2                           NaN                         NaN    Normal
# 3                           NaN                         NaN    Normal
# 4                           NaN                         NaN    Normal
# ...                         ...                         ...       ...
# 40501                       NaN                         NaN    Normal
# 40502                       NaN                         NaN    Normal
# 40503                       NaN                         NaN    Normal
# 40504                       NaN                         NaN    Normal
# 40505                       NaN                         NaN  AbNormal
#
# [40506 rows x 464 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40506 entries, 0 to 40505
# Columns: 464 entries, Wip Line_Dam to target
# dtypes: float64(350), int64(77), object(37)
# memory usage: 143.4+ MB

# %%
train_data.shape[0]
# Out:
# 40506

# %%
df = train_data.copy()

# %%
# 각 열별 결측치 개수 확인
missing_values_count = (df.isnull().sum())
missing_values_count = missing_values_count/df.shape[0] 
missing_values_ratio = missing_values_count * 100
print(missing_values_ratio)
# Out:
# Wip Line_Dam                       0.0
# Process Desc._Dam                  0.0
# Equipment_Dam                      0.0
# Model.Suffix_Dam                   0.0
# Workorder_Dam                      0.0
#                                  ...
# Receip No Judge Value_Fill2      100.0
# WorkMode Collect Result_Fill2      0.0
# WorkMode Unit Time_Fill2         100.0
# WorkMode Judge Value_Fill2       100.0
# target                             0.0
# Length: 464, dtype: float64

# %%
bins = [0, 20, 40, 60, 80, 100]
missing_values_counts = pd.cut(missing_values_ratio, bins=bins).value_counts().sort_index()

print(missing_values_counts)
# Out:
# (0, 20]        0
# (20, 40]       3
# (40, 60]       0
# (60, 80]       5
# (80, 100]    278
# Name: count, dtype: int64

# %% [markdown]
# (20, 40]에 대해서는 결측치를 채우는 과정을 수행한다.

# %%
# 결측치 비율이 80 이상인 열 삭제
threshold = 80
df= df.drop(columns=missing_values_ratio[missing_values_ratio >= threshold].index)

df.info
# Out:
# <bound method DataFrame.info of       Wip Line_Dam Process Desc._Dam     Equipment_Dam Model.Suffix_Dam  \
# 0          IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334505
# 1          IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334505
# 2          IVI-OB6     Dam Dispenser  Dam dispenser #2      AJX75334501
# 3          IVI-OB6     Dam Dispenser  Dam dispenser #2      AJX75334501
# 4          IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334501
# ...            ...               ...               ...              ...
# 40501      IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334501
# 40502      IVI-OB6     Dam Dispenser  Dam dispenser #2      AJX75334501
# 40503      IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334501
# 40504      IVI-OB6     Dam Dispenser  Dam dispenser #2      AJX75334501
# 40505      IVI-OB6     Dam Dispenser  Dam dispenser #1      AJX75334501
#
#       Workorder_Dam  Insp. Seq No._Dam Insp Judge Code_Dam  \
# 0        4F1XA938-1                  1                  OK
# 1        3KPM0016-2                  1                  OK
# 2        4E1X9167-1                  1                  OK
# 3        3K1X0057-1                  1                  OK
# 4        3HPM0007-1                  1                  OK
# ...             ...                ...                 ...
# 40501    3J1XF434-2                  1                  OK
# 40502    4E1XC796-1                  1                  OK
# 40503    4C1XD438-1                  1                  OK
# 40504    3I1XA258-1                  1                  OK
# 40505    3G1XA501-1                  1                  OK
#
#        CURE END POSITION X Collect Result_Dam  \
# 0                                       240.0
# 1                                       240.0
# 2                                      1000.0
# 3                                      1000.0
# 4                                       240.0
# ...                                       ...
# 40501                                   240.0
# 40502                                  1000.0
# 40503                                   240.0
# 40504                                  1000.0
# 40505                                   240.0
#
#        CURE END POSITION Z Collect Result_Dam  \
# 0                                         2.5
# 1                                         2.5
# 2                                        12.5
# 3                                        12.5
# 4                                         2.5
# ...                                       ...
# 40501                                     2.5
# 40502                                    12.5
# 40503                                     2.5
# 40504                                    12.5
# 40505                                     2.5
#
#        CURE END POSITION Θ Collect Result_Dam  ...  \
# 0                                         -90  ...
# 1                                         -90  ...
# 2                                          90  ...
# 3                                          90  ...
# 4                                         -90  ...
# ...                                       ...  ...
# 40501                                     -90  ...
# 40502                                      90  ...
# 40503                                     -90  ...
# 40504                                      90  ...
# 40505                                     -90  ...
#
#        Head Clean Position Z Collect Result_Fill2  \
# 0                                            50.0
# 1                                            91.8
# 2                                            50.0
# 3                                            91.8
# 4                                            91.8
# ...                                           ...
# 40501                                        91.8
# 40502                                        50.0
# 40503                                        50.0
# 40504                                        91.8
# 40505                                        91.8
#
#        Head Purge Position X Collect Result_Fill2  \
# 0                                            91.8
# 1                                           270.0
# 2                                            91.8
# 3                                           270.0
# 4                                           270.0
# ...                                           ...
# 40501                                       270.0
# 40502                                        91.8
# 40503                                        91.8
# 40504                                       270.0
# 40505                                       270.0
#
#        Head Purge Position Y Collect Result_Fill2  \
# 0                                             270
# 1                                              50
# 2                                             270
# 3                                              50
# 4                                              50
# ...                                           ...
# 40501                                          50
# 40502                                         270
# 40503                                         270
# 40504                                          50
# 40505                                          50
#
#        Head Purge Position Z Collect Result_Fill2  \
# 0                                              50
# 1                                              85
# 2                                              50
# 3                                              85
# 4                                              85
# ...                                           ...
# 40501                                          85
# 40502                                          50
# 40503                                          50
# 40504                                          85
# 40505                                          85
#
#        Machine Tact time Collect Result_Fill2  PalletID Collect Result_Fill2  \
# 0                                     114.612                           19.9
# 1                                      19.600                            7.0
# 2                                     114.612                           19.8
# 3                                      19.900                           12.0
# 4                                      19.700                            8.0
# ...                                       ...                            ...
# 40501                                  19.200                            1.0
# 40502                                 114.612                           20.5
# 40503                                  85.000                           19.7
# 40504                                  20.100                           13.0
# 40505                                  19.400                            3.0
#
#        Production Qty Collect Result_Fill2  Receip No Collect Result_Fill2  \
# 0                                        7                             127
# 1                                      185                               1
# 2                                       10                              73
# 3                                      268                               1
# 4                                      121                               1
# ...                                    ...                             ...
# 40501                                  318                               1
# 40502                                   14                             197
# 40503                                    1                              27
# 40504                                  117                               1
# 40505                                  320                               1
#
#        WorkMode Collect Result_Fill2    target
# 0                                  1    Normal
# 1                                  0    Normal
# 2                                  1    Normal
# 3                                  0    Normal
# 4                                  0    Normal
# ...                              ...       ...
# 40501                              0    Normal
# 40502                              1    Normal
# 40503                              1    Normal
# 40504                              0    Normal
# 40505                              0  AbNormal
#
# [40506 rows x 186 columns]>

# %% [markdown]
# 칼럼들을 각 공정 단계 별로 구별한다.

# %%
# "Process Desc"를 포함하는 열의 인덱스 찾기
process_columns = [col for col in df.columns if "Process Desc" in col]
process_indices = [df.columns.get_loc(col) for col in process_columns]

# 새로운 DataFrame을 저장할 딕셔너리 초기화
dfs = {}

# Process Desc에 따라 DataFrame을 나누어 저장
for i, start_idx in enumerate(process_indices):
    end_idx = process_indices[i + 1]-1 if i + 1 < len(process_indices) else len(df.columns)-1
    
    # 각 Process Desc와 그에 해당하는 환경 변수들을 포함하는 DataFrame 생성
    relevant_columns = df.columns[start_idx:end_idx]
    dfs[f'df{i+1}'] = df[relevant_columns]

# 나눠진 DataFrame들을 확인
for name, df_subset in dfs.items():
    print(f'{name}:')
    print(df_subset)
    print('\n')
# Out:
# df1:
#       Process Desc._Dam     Equipment_Dam Model.Suffix_Dam Workorder_Dam  \
# 0         Dam Dispenser  Dam dispenser #1      AJX75334505    4F1XA938-1
# 1         Dam Dispenser  Dam dispenser #1      AJX75334505    3KPM0016-2
# 2         Dam Dispenser  Dam dispenser #2      AJX75334501    4E1X9167-1
# 3         Dam Dispenser  Dam dispenser #2      AJX75334501    3K1X0057-1
# 4         Dam Dispenser  Dam dispenser #1      AJX75334501    3HPM0007-1
# ...                 ...               ...              ...           ...
# 40501     Dam Dispenser  Dam dispenser #1      AJX75334501    3J1XF434-2
# 40502     Dam Dispenser  Dam dispenser #2      AJX75334501    4E1XC796-1
# 40503     Dam Dispenser  Dam dispenser #1      AJX75334501    4C1XD438-1
# 40504     Dam Dispenser  Dam dispenser #2      AJX75334501    3I1XA258-1
# 40505     Dam Dispenser  Dam dispenser #1      AJX75334501    3G1XA501-1
#
#        Insp. Seq No._Dam Insp Judge Code_Dam  \
# 0                      1                  OK
# 1                      1                  OK
# 2                      1                  OK
# 3                      1                  OK
# 4                      1                  OK
# ...                  ...                 ...
# 40501                  1                  OK
# 40502                  1                  OK
# 40503                  1                  OK
# 40504                  1                  OK
# 40505                  1                  OK
#
#        CURE END POSITION X Collect Result_Dam  \
# 0                                       240.0
# 1                                       240.0
# 2                                      1000.0
# 3                                      1000.0
# 4                                       240.0
# ...                                       ...
# 40501                                   240.0
# 40502                                  1000.0
# 40503                                   240.0
# 40504                                  1000.0
# 40505                                   240.0
#
#        CURE END POSITION Z Collect Result_Dam  \
# 0                                         2.5
# 1                                         2.5
# 2                                        12.5
# 3                                        12.5
# 4                                         2.5
# ...                                       ...
# 40501                                     2.5
# 40502                                    12.5
# 40503                                     2.5
# 40504                                    12.5
# 40505                                     2.5
#
#        CURE END POSITION Θ Collect Result_Dam  CURE SPEED Collect Result_Dam  \
# 0                                         -90                            100
# 1                                         -90                             70
# 2                                          90                             85
# 3                                          90                             70
# 4                                         -90                             70
# ...                                       ...                            ...
# 40501                                     -90                             70
# 40502                                      90                            100
# 40503                                     -90                            100
# 40504                                      90                             70
# 40505                                     -90                             70
#
#        ...  Stage3 Circle3 Distance Speed Collect Result_Dam  \
# 0      ...                                              5800
# 1      ...                                              4000
# 2      ...                                              5800
# 3      ...                                              4000
# 4      ...                                              9000
# ...    ...                                               ...
# 40501  ...                                              5000
# 40502  ...                                              5800
# 40503  ...                                              6000
# 40504  ...                                              9000
# 40505  ...                                              9000
#
#        Stage3 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        THICKNESS 1 Collect Result_Dam  THICKNESS 2 Collect Result_Dam  \
# 0                                5800                           0.000
# 1                                   0                           0.000
# 2                                5800                           0.012
# 3                                   0                           0.000
# 4                                   0                           0.000
# ...                               ...                             ...
# 40501                               0                           0.000
# 40502                            5800                          -0.019
# 40503                            6000                           0.000
# 40504                               0                           0.000
# 40505                               0                           0.000
#
#        THICKNESS 3 Collect Result_Dam  WorkMode Collect Result_Dam
# 0                               0.000                        0.000
# 1                               0.000                        7.000
# 2                              -0.022                        0.003
# 3                               0.000                        7.000
# 4                               0.000                        7.000
# ...                               ...                          ...
# 40501                           0.000                        7.000
# 40502                          -0.021                       -0.118
# 40503                           0.000                        0.000
# 40504                           0.000                        7.000
# 40505                           0.000                        7.000
#
# [40506 rows x 77 columns]
#
#
# df2:
#       Process Desc._AutoClave Equipment_AutoClave Model.Suffix_AutoClave  \
# 0              Auto Clave Out      Auto Clave Out            AJX75334505
# 1              Auto Clave Out      Auto Clave Out            AJX75334505
# 2              Auto Clave Out      Auto Clave Out            AJX75334501
# 3              Auto Clave Out      Auto Clave Out            AJX75334501
# 4              Auto Clave Out      Auto Clave Out            AJX75334501
# ...                       ...                 ...                    ...
# 40501          Auto Clave Out      Auto Clave Out            AJX75334501
# 40502          Auto Clave Out      Auto Clave Out            AJX75334501
# 40503          Auto Clave Out      Auto Clave Out            AJX75334501
# 40504          Auto Clave Out      Auto Clave Out            AJX75334501
# 40505          Auto Clave Out      Auto Clave Out            AJX75334501
#
#       Workorder_AutoClave  Insp. Seq No._AutoClave Insp Judge Code_AutoClave  \
# 0              4F1XA938-1                        1                        OK
# 1              3KPM0016-2                        1                        OK
# 2              4E1X9167-1                        1                        OK
# 3              3K1X0057-1                        1                        OK
# 4              3HPM0007-1                        1                        OK
# ...                   ...                      ...                       ...
# 40501          3J1XF434-2                        1                        OK
# 40502          4E1XC796-1                        1                        OK
# 40503          4C1XD438-1                        1                        OK
# 40504          3I1XA258-1                        1                        OK
# 40505          3G1XA501-1                        1                        OK
#
#        1st Pressure Collect Result_AutoClave  \
# 0                                      0.312
# 1                                      0.311
# 2                                      0.315
# 3                                      0.299
# 4                                      0.302
# ...                                      ...
# 40501                                  0.300
# 40502                                  0.305
# 40503                                  0.309
# 40504                                  0.302
# 40505                                  0.305
#
#        1st Pressure 1st Pressure Unit Time_AutoClave  \
# 0                                                240
# 1                                                241
# 2                                                241
# 3                                                241
# 4                                                240
# ...                                              ...
# 40501                                            241
# 40502                                            240
# 40503                                            241
# 40504                                            241
# 40505                                            300
#
#       1st Pressure Judge Value_AutoClave  \
# 0                                     OK
# 1                                     OK
# 2                                     OK
# 3                                     OK
# 4                                     OK
# ...                                  ...
# 40501                                 OK
# 40502                                 OK
# 40503                                 OK
# 40504                                 OK
# 40505                                 OK
#
#        2nd Pressure Collect Result_AutoClave  \
# 0                                      0.493
# 1                                      0.311
# 2                                      0.490
# 3                                      0.300
# 4                                      0.302
# ...                                      ...
# 40501                                  0.300
# 40502                                  0.493
# 40503                                  0.490
# 40504                                  0.303
# 40505                                  0.305
#
#        2nd Pressure Unit Time_AutoClave 2nd Pressure Judge Value_AutoClave  \
# 0                                     1                                 OK
# 1                                   121                                 OK
# 2                                     1                                 OK
# 3                                   121                                 OK
# 4                                   120                                 OK
# ...                                 ...                                ...
# 40501                               121                                 OK
# 40502                                 1                                 OK
# 40503                                 1                                 OK
# 40504                               121                                 OK
# 40505                                60                                 OK
#
#        3rd Pressure Collect Result_AutoClave  \
# 0                                      0.499
# 1                                      0.498
# 2                                      0.498
# 3                                      0.500
# 4                                      0.498
# ...                                      ...
# 40501                                  0.500
# 40502                                  0.498
# 40503                                  0.498
# 40504                                  0.499
# 40505                                  0.498
#
#        3rd Pressure Unit Time_AutoClave 3rd Pressure Judge Value_AutoClave  \
# 0                                   120                                 OK
# 1                                   121                                 OK
# 2                                   121                                 OK
# 3                                   121                                 OK
# 4                                   120                                 OK
# ...                                 ...                                ...
# 40501                               121                                 OK
# 40502                               120                                 OK
# 40503                               121                                 OK
# 40504                               121                                 OK
# 40505                               120                                 OK
#
#        Chamber Temp. Collect Result_AutoClave  \
# 0                                          54
# 1                                          54
# 2                                          56
# 3                                          54
# 4                                          47
# ...                                       ...
# 40501                                      54
# 40502                                      49
# 40503                                      48
# 40504                                      54
# 40505                                      47
#
#        Chamber Temp. Unit Time_AutoClave Chamber Temp. Judge Value_AutoClave  \
# 0                                    361                                  OK
# 1                                    483                                  OK
# 2                                    363                                  OK
# 3                                    483                                  OK
# 4                                    480                                  NG
# ...                                  ...                                 ...
# 40501                                483                                  OK
# 40502                                361                                  NG
# 40503                                363                                  NG
# 40504                                483                                  OK
# 40505                                480                                  NG
#
#       GMES_ORIGIN_INSP_JUDGE_CODE Collect Result_AutoClave  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                     OK
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                 OK
# 40504                                                NaN
# 40505                                                NaN
#
#       GMES_ORIGIN_INSP_JUDGE_CODE Judge Value_AutoClave
# 0                                                   NaN
# 1                                                   NaN
# 2                                                    OK
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 40501                                               NaN
# 40502                                               NaN
# 40503                                                OK
# 40504                                               NaN
# 40505                                               NaN
#
# [40506 rows x 20 columns]
#
#
# df3:
#       Process Desc._Fill1     Equipment_Fill1 Model.Suffix_Fill1  \
# 0         Fill1 Dispenser  Fill1 dispenser #1        AJX75334505
# 1         Fill1 Dispenser  Fill1 dispenser #1        AJX75334505
# 2         Fill1 Dispenser  Fill1 dispenser #2        AJX75334501
# 3         Fill1 Dispenser  Fill1 dispenser #2        AJX75334501
# 4         Fill1 Dispenser  Fill1 dispenser #1        AJX75334501
# ...                   ...                 ...                ...
# 40501     Fill1 Dispenser  Fill1 dispenser #1        AJX75334501
# 40502     Fill1 Dispenser  Fill1 dispenser #2        AJX75334501
# 40503     Fill1 Dispenser  Fill1 dispenser #1        AJX75334501
# 40504     Fill1 Dispenser  Fill1 dispenser #2        AJX75334501
# 40505     Fill1 Dispenser  Fill1 dispenser #1        AJX75334501
#
#       Workorder_Fill1  Insp. Seq No._Fill1 Insp Judge Code_Fill1  \
# 0          4F1XA938-1                    1                    OK
# 1          3KPM0016-2                    1                    OK
# 2          4E1X9167-1                    1                    OK
# 3          3K1X0057-1                    1                    OK
# 4          3HPM0007-1                    1                    OK
# ...               ...                  ...                   ...
# 40501      3J1XF434-2                    1                    OK
# 40502      4E1XC796-1                    1                    OK
# 40503      4C1XD438-1                    1                    OK
# 40504      3I1XA258-1                    1                    OK
# 40505      3G1XA501-1                    1                    OK
#
#        DISCHARGED SPEED OF RESIN Collect Result_Fill1  \
# 0                                                10.6
# 1                                                10.6
# 2                                                10.6
# 3                                                10.6
# 4                                                10.6
# ...                                               ...
# 40501                                            10.6
# 40502                                            10.6
# 40503                                            10.6
# 40504                                            10.6
# 40505                                            10.9
#
#        DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill1  \
# 0                                                   12.7
# 1                                                   13.5
# 2                                                   13.5
# 3                                                   13.5
# 4                                                   13.5
# ...                                                  ...
# 40501                                               13.5
# 40502                                               13.5
# 40503                                               12.9
# 40504                                               13.5
# 40505                                               13.4
#
#        DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill1  \
# 0                                                    3.6
# 1                                                    3.6
# 2                                                    3.5
# 3                                                    3.6
# 4                                                    3.6
# ...                                                  ...
# 40501                                                3.6
# 40502                                                3.6
# 40503                                                3.6
# 40504                                                3.6
# 40505                                                5.0
#
#        DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill1  ...  \
# 0                                                   12.6      ...
# 1                                                   13.5      ...
# 2                                                   13.4      ...
# 3                                                   13.5      ...
# 4                                                   13.5      ...
# ...                                                  ...      ...
# 40501                                               13.5      ...
# 40502                                               13.5      ...
# 40503                                               12.9      ...
# 40504                                               13.4      ...
# 40505                                               13.4      ...
#
#        Head Clean Position Y Collect Result_Fill1  \
# 0                                           123.4
# 1                                            50.0
# 2                                           123.4
# 3                                            50.0
# 4                                            50.0
# ...                                           ...
# 40501                                        50.0
# 40502                                       123.4
# 40503                                       123.4
# 40504                                        50.0
# 40505                                        50.0
#
#        Head Clean Position Z Collect Result_Fill1  \
# 0                                            50.0
# 1                                            92.2
# 2                                            50.0
# 3                                            92.2
# 4                                            92.2
# ...                                           ...
# 40501                                        92.2
# 40502                                        50.0
# 40503                                        50.0
# 40504                                        92.2
# 40505                                        92.2
#
#        Head Purge Position X Collect Result_Fill1  \
# 0                                            92.2
# 1                                           289.0
# 2                                            92.2
# 3                                           289.0
# 4                                           289.0
# ...                                           ...
# 40501                                       289.0
# 40502                                        92.2
# 40503                                        92.2
# 40504                                       289.0
# 40505                                       289.0
#
#       Head Purge Position Y Collect Result_Fill1  \
# 0                                            289
# 1                                             50
# 2                                            289
# 3                                             50
# 4                                             50
# ...                                          ...
# 40501                                         50
# 40502                                        289
# 40503                                        289
# 40504                                         50
# 40505                                         50
#
#       Head Purge Position Z Collect Result_Fill1  \
# 0                                             50
# 1                                            145
# 2                                             50
# 3                                            145
# 4                                             85
# ...                                          ...
# 40501                                        145
# 40502                                         50
# 40503                                         50
# 40504                                        145
# 40505                                         85
#
#        Machine Tact time Collect Result_Fill1  PalletID Collect Result_Fill1  \
# 0                                       128.0                           55.7
# 1                                        56.5                            7.0
# 2                                       128.0                           58.7
# 3                                        57.7                           12.0
# 4                                        89.9                            8.0
# ...                                       ...                            ...
# 40501                                    51.8                            1.0
# 40502                                   128.0                           58.7
# 40503                                   128.0                           56.2
# 40504                                    57.4                           13.0
# 40505                                    91.5                            3.0
#
#        Production Qty Collect Result_Fill1  Receip No Collect Result_Fill1  \
# 0                                        7                             127
# 1                                      185                               1
# 2                                       10                              73
# 3                                      268                               1
# 4                                      121                               1
# ...                                    ...                             ...
# 40501                                  318                               1
# 40502                                   14                             197
# 40503                                    1                              27
# 40504                                  117                               1
# 40505                                  320                               1
#
#        WorkMode Collect Result_Fill1
# 0                                  1
# 1                                  7
# 2                                  1
# 3                                  7
# 4                                  7
# ...                              ...
# 40501                              7
# 40502                              1
# 40503                              1
# 40504                              7
# 40505                              7
#
# [40506 rows x 37 columns]
#
#
# df4:
#       Process Desc._Fill2     Equipment_Fill2 Model.Suffix_Fill2  \
# 0         Fill2 Dispenser  Fill2 dispenser #1        AJX75334505
# 1         Fill2 Dispenser  Fill2 dispenser #1        AJX75334505
# 2         Fill2 Dispenser  Fill2 dispenser #2        AJX75334501
# 3         Fill2 Dispenser  Fill2 dispenser #2        AJX75334501
# 4         Fill2 Dispenser  Fill2 dispenser #1        AJX75334501
# ...                   ...                 ...                ...
# 40501     Fill2 Dispenser  Fill2 dispenser #1        AJX75334501
# 40502     Fill2 Dispenser  Fill2 dispenser #2        AJX75334501
# 40503     Fill2 Dispenser  Fill2 dispenser #1        AJX75334501
# 40504     Fill2 Dispenser  Fill2 dispenser #2        AJX75334501
# 40505     Fill2 Dispenser  Fill2 dispenser #1        AJX75334501
#
#       Workorder_Fill2  Insp. Seq No._Fill2 Insp Judge Code_Fill2  \
# 0          4F1XA938-1                    1                    OK
# 1          3KPM0016-2                    1                    OK
# 2          4E1X9167-1                    1                    OK
# 3          3K1X0057-1                    1                    OK
# 4          3HPM0007-1                    1                    OK
# ...               ...                  ...                   ...
# 40501      3J1XF434-2                    1                    OK
# 40502      4E1XC796-1                    1                    OK
# 40503      4C1XD438-1                    1                    OK
# 40504      3I1XA258-1                    1                    OK
# 40505      3G1XA501-1                    1                    OK
#
#        CURE END POSITION X Collect Result_Fill2  \
# 0                                           240
# 1                                           240
# 2                                           240
# 3                                           240
# 4                                           240
# ...                                         ...
# 40501                                       240
# 40502                                       240
# 40503                                       240
# 40504                                       240
# 40505                                       240
#
#        CURE END POSITION Z Collect Result_Fill2  \
# 0                                            33
# 1                                            33
# 2                                            33
# 3                                            33
# 4                                            32
# ...                                         ...
# 40501                                        33
# 40502                                        33
# 40503                                        33
# 40504                                        33
# 40505                                        32
#
#        CURE END POSITION Θ Collect Result_Fill2  \
# 0                                           -90
# 1                                           -90
# 2                                           -90
# 3                                           -90
# 4                                           -90
# ...                                         ...
# 40501                                       -90
# 40502                                       -90
# 40503                                       -90
# 40504                                       -90
# 40505                                       -90
#
#        CURE SPEED Collect Result_Fill2  ...  \
# 0                                   48  ...
# 1                                   50  ...
# 2                                   50  ...
# 3                                   50  ...
# 4                                   50  ...
# ...                                ...  ...
# 40501                               50  ...
# 40502                               48  ...
# 40503                               50  ...
# 40504                               50  ...
# 40505                               50  ...
#
#        Head Clean Position Y Collect Result_Fill2  \
# 0                                             119
# 1                                              50
# 2                                             119
# 3                                              50
# 4                                              50
# ...                                           ...
# 40501                                          50
# 40502                                         119
# 40503                                         119
# 40504                                          50
# 40505                                          50
#
#        Head Clean Position Z Collect Result_Fill2  \
# 0                                            50.0
# 1                                            91.8
# 2                                            50.0
# 3                                            91.8
# 4                                            91.8
# ...                                           ...
# 40501                                        91.8
# 40502                                        50.0
# 40503                                        50.0
# 40504                                        91.8
# 40505                                        91.8
#
#        Head Purge Position X Collect Result_Fill2  \
# 0                                            91.8
# 1                                           270.0
# 2                                            91.8
# 3                                           270.0
# 4                                           270.0
# ...                                           ...
# 40501                                       270.0
# 40502                                        91.8
# 40503                                        91.8
# 40504                                       270.0
# 40505                                       270.0
#
#        Head Purge Position Y Collect Result_Fill2  \
# 0                                             270
# 1                                              50
# 2                                             270
# 3                                              50
# 4                                              50
# ...                                           ...
# 40501                                          50
# 40502                                         270
# 40503                                         270
# 40504                                          50
# 40505                                          50
#
#        Head Purge Position Z Collect Result_Fill2  \
# 0                                              50
# 1                                              85
# 2                                              50
# 3                                              85
# 4                                              85
# ...                                           ...
# 40501                                          85
# 40502                                          50
# 40503                                          50
# 40504                                          85
# 40505                                          85
#
#        Machine Tact time Collect Result_Fill2  PalletID Collect Result_Fill2  \
# 0                                     114.612                           19.9
# 1                                      19.600                            7.0
# 2                                     114.612                           19.8
# 3                                      19.900                           12.0
# 4                                      19.700                            8.0
# ...                                       ...                            ...
# 40501                                  19.200                            1.0
# 40502                                 114.612                           20.5
# 40503                                  85.000                           19.7
# 40504                                  20.100                           13.0
# 40505                                  19.400                            3.0
#
#        Production Qty Collect Result_Fill2  Receip No Collect Result_Fill2  \
# 0                                        7                             127
# 1                                      185                               1
# 2                                       10                              73
# 3                                      268                               1
# 4                                      121                               1
# ...                                    ...                             ...
# 40501                                  318                               1
# 40502                                   14                             197
# 40503                                    1                              27
# 40504                                  117                               1
# 40505                                  320                               1
#
#        WorkMode Collect Result_Fill2
# 0                                  1
# 1                                  0
# 2                                  1
# 3                                  0
# 4                                  0
# ...                              ...
# 40501                              0
# 40502                              1
# 40503                              1
# 40504                              0
# 40505                              0
#
# [40506 rows x 47 columns]

# %%
df1 = dfs['df1']
df2 = dfs['df2']
df3 = dfs['df3']
df4 = dfs['df4']

# %%
target = df['target']

# %%
df1
# Out:
#       Process Desc._Dam     Equipment_Dam Model.Suffix_Dam Workorder_Dam  \
# 0         Dam Dispenser  Dam dispenser #1      AJX75334505    4F1XA938-1
# 1         Dam Dispenser  Dam dispenser #1      AJX75334505    3KPM0016-2
# 2         Dam Dispenser  Dam dispenser #2      AJX75334501    4E1X9167-1
# 3         Dam Dispenser  Dam dispenser #2      AJX75334501    3K1X0057-1
# 4         Dam Dispenser  Dam dispenser #1      AJX75334501    3HPM0007-1
# ...                 ...               ...              ...           ...
# 40501     Dam Dispenser  Dam dispenser #1      AJX75334501    3J1XF434-2
# 40502     Dam Dispenser  Dam dispenser #2      AJX75334501    4E1XC796-1
# 40503     Dam Dispenser  Dam dispenser #1      AJX75334501    4C1XD438-1
# 40504     Dam Dispenser  Dam dispenser #2      AJX75334501    3I1XA258-1
# 40505     Dam Dispenser  Dam dispenser #1      AJX75334501    3G1XA501-1
#
#        Insp. Seq No._Dam Insp Judge Code_Dam  \
# 0                      1                  OK
# 1                      1                  OK
# 2                      1                  OK
# 3                      1                  OK
# 4                      1                  OK
# ...                  ...                 ...
# 40501                  1                  OK
# 40502                  1                  OK
# 40503                  1                  OK
# 40504                  1                  OK
# 40505                  1                  OK
#
#        CURE END POSITION X Collect Result_Dam  \
# 0                                       240.0
# 1                                       240.0
# 2                                      1000.0
# 3                                      1000.0
# 4                                       240.0
# ...                                       ...
# 40501                                   240.0
# 40502                                  1000.0
# 40503                                   240.0
# 40504                                  1000.0
# 40505                                   240.0
#
#        CURE END POSITION Z Collect Result_Dam  \
# 0                                         2.5
# 1                                         2.5
# 2                                        12.5
# 3                                        12.5
# 4                                         2.5
# ...                                       ...
# 40501                                     2.5
# 40502                                    12.5
# 40503                                     2.5
# 40504                                    12.5
# 40505                                     2.5
#
#        CURE END POSITION Θ Collect Result_Dam  CURE SPEED Collect Result_Dam  \
# 0                                         -90                            100
# 1                                         -90                             70
# 2                                          90                             85
# 3                                          90                             70
# 4                                         -90                             70
# ...                                       ...                            ...
# 40501                                     -90                             70
# 40502                                      90                            100
# 40503                                     -90                            100
# 40504                                      90                             70
# 40505                                     -90                             70
#
#        ...  Stage3 Circle3 Distance Speed Collect Result_Dam  \
# 0      ...                                              5800
# 1      ...                                              4000
# 2      ...                                              5800
# 3      ...                                              4000
# 4      ...                                              9000
# ...    ...                                               ...
# 40501  ...                                              5000
# 40502  ...                                              5800
# 40503  ...                                              6000
# 40504  ...                                              9000
# 40505  ...                                              9000
#
#        Stage3 Circle4 Distance Speed Collect Result_Dam  \
# 0                                                  5800
# 1                                                  4000
# 2                                                  5800
# 3                                                  4000
# 4                                                  9000
# ...                                                 ...
# 40501                                              5000
# 40502                                              5800
# 40503                                              6000
# 40504                                              9000
# 40505                                              9000
#
#        Stage3 Line1 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line2 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line3 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        Stage3 Line4 Distance Speed Collect Result_Dam  \
# 0                                                5800
# 1                                                4000
# 2                                                5800
# 3                                                4000
# 4                                                9000
# ...                                               ...
# 40501                                            5000
# 40502                                            5800
# 40503                                            6000
# 40504                                            9000
# 40505                                            9000
#
#        THICKNESS 1 Collect Result_Dam  THICKNESS 2 Collect Result_Dam  \
# 0                                5800                           0.000
# 1                                   0                           0.000
# 2                                5800                           0.012
# 3                                   0                           0.000
# 4                                   0                           0.000
# ...                               ...                             ...
# 40501                               0                           0.000
# 40502                            5800                          -0.019
# 40503                            6000                           0.000
# 40504                               0                           0.000
# 40505                               0                           0.000
#
#        THICKNESS 3 Collect Result_Dam  WorkMode Collect Result_Dam
# 0                               0.000                        0.000
# 1                               0.000                        7.000
# 2                              -0.022                        0.003
# 3                               0.000                        7.000
# 4                               0.000                        7.000
# ...                               ...                          ...
# 40501                           0.000                        7.000
# 40502                          -0.021                       -0.118
# 40503                           0.000                        0.000
# 40504                           0.000                        7.000
# 40505                           0.000                        7.000
#
# [40506 rows x 77 columns]

# %%
df2
# Out:
#       Process Desc._AutoClave Equipment_AutoClave Model.Suffix_AutoClave  \
# 0              Auto Clave Out      Auto Clave Out            AJX75334505
# 1              Auto Clave Out      Auto Clave Out            AJX75334505
# 2              Auto Clave Out      Auto Clave Out            AJX75334501
# 3              Auto Clave Out      Auto Clave Out            AJX75334501
# 4              Auto Clave Out      Auto Clave Out            AJX75334501
# ...                       ...                 ...                    ...
# 40501          Auto Clave Out      Auto Clave Out            AJX75334501
# 40502          Auto Clave Out      Auto Clave Out            AJX75334501
# 40503          Auto Clave Out      Auto Clave Out            AJX75334501
# 40504          Auto Clave Out      Auto Clave Out            AJX75334501
# 40505          Auto Clave Out      Auto Clave Out            AJX75334501
#
#       Workorder_AutoClave  Insp. Seq No._AutoClave Insp Judge Code_AutoClave  \
# 0              4F1XA938-1                        1                        OK
# 1              3KPM0016-2                        1                        OK
# 2              4E1X9167-1                        1                        OK
# 3              3K1X0057-1                        1                        OK
# 4              3HPM0007-1                        1                        OK
# ...                   ...                      ...                       ...
# 40501          3J1XF434-2                        1                        OK
# 40502          4E1XC796-1                        1                        OK
# 40503          4C1XD438-1                        1                        OK
# 40504          3I1XA258-1                        1                        OK
# 40505          3G1XA501-1                        1                        OK
#
#        1st Pressure Collect Result_AutoClave  \
# 0                                      0.312
# 1                                      0.311
# 2                                      0.315
# 3                                      0.299
# 4                                      0.302
# ...                                      ...
# 40501                                  0.300
# 40502                                  0.305
# 40503                                  0.309
# 40504                                  0.302
# 40505                                  0.305
#
#        1st Pressure 1st Pressure Unit Time_AutoClave  \
# 0                                                240
# 1                                                241
# 2                                                241
# 3                                                241
# 4                                                240
# ...                                              ...
# 40501                                            241
# 40502                                            240
# 40503                                            241
# 40504                                            241
# 40505                                            300
#
#       1st Pressure Judge Value_AutoClave  \
# 0                                     OK
# 1                                     OK
# 2                                     OK
# 3                                     OK
# 4                                     OK
# ...                                  ...
# 40501                                 OK
# 40502                                 OK
# 40503                                 OK
# 40504                                 OK
# 40505                                 OK
#
#        2nd Pressure Collect Result_AutoClave  \
# 0                                      0.493
# 1                                      0.311
# 2                                      0.490
# 3                                      0.300
# 4                                      0.302
# ...                                      ...
# 40501                                  0.300
# 40502                                  0.493
# 40503                                  0.490
# 40504                                  0.303
# 40505                                  0.305
#
#        2nd Pressure Unit Time_AutoClave 2nd Pressure Judge Value_AutoClave  \
# 0                                     1                                 OK
# 1                                   121                                 OK
# 2                                     1                                 OK
# 3                                   121                                 OK
# 4                                   120                                 OK
# ...                                 ...                                ...
# 40501                               121                                 OK
# 40502                                 1                                 OK
# 40503                                 1                                 OK
# 40504                               121                                 OK
# 40505                                60                                 OK
#
#        3rd Pressure Collect Result_AutoClave  \
# 0                                      0.499
# 1                                      0.498
# 2                                      0.498
# 3                                      0.500
# 4                                      0.498
# ...                                      ...
# 40501                                  0.500
# 40502                                  0.498
# 40503                                  0.498
# 40504                                  0.499
# 40505                                  0.498
#
#        3rd Pressure Unit Time_AutoClave 3rd Pressure Judge Value_AutoClave  \
# 0                                   120                                 OK
# 1                                   121                                 OK
# 2                                   121                                 OK
# 3                                   121                                 OK
# 4                                   120                                 OK
# ...                                 ...                                ...
# 40501                               121                                 OK
# 40502                               120                                 OK
# 40503                               121                                 OK
# 40504                               121                                 OK
# 40505                               120                                 OK
#
#        Chamber Temp. Collect Result_AutoClave  \
# 0                                          54
# 1                                          54
# 2                                          56
# 3                                          54
# 4                                          47
# ...                                       ...
# 40501                                      54
# 40502                                      49
# 40503                                      48
# 40504                                      54
# 40505                                      47
#
#        Chamber Temp. Unit Time_AutoClave Chamber Temp. Judge Value_AutoClave  \
# 0                                    361                                  OK
# 1                                    483                                  OK
# 2                                    363                                  OK
# 3                                    483                                  OK
# 4                                    480                                  NG
# ...                                  ...                                 ...
# 40501                                483                                  OK
# 40502                                361                                  NG
# 40503                                363                                  NG
# 40504                                483                                  OK
# 40505                                480                                  NG
#
#       GMES_ORIGIN_INSP_JUDGE_CODE Collect Result_AutoClave  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                     OK
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                 OK
# 40504                                                NaN
# 40505                                                NaN
#
#       GMES_ORIGIN_INSP_JUDGE_CODE Judge Value_AutoClave
# 0                                                   NaN
# 1                                                   NaN
# 2                                                    OK
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 40501                                               NaN
# 40502                                               NaN
# 40503                                                OK
# 40504                                               NaN
# 40505                                               NaN
#
# [40506 rows x 20 columns]

# %% [markdown]
# 상수 변수 탐지 : 모든 항이 동일한 상수 변수의 경우 가치가 존재하지 않는다.

# %%
# 상수 열 찾기
constant_columns1 = [col for col in df1.columns if df1[col].nunique() == 1]
constant_columns1
# Out:
# ['Process Desc._Dam',
#  'Insp. Seq No._Dam',
#  'Insp Judge Code_Dam',
#  'CURE STANDBY POSITION X Collect Result_Dam',
#  'CURE STANDBY POSITION Z Collect Result_Dam',
#  'CURE STANDBY POSITION Θ Collect Result_Dam',
#  'CURE START POSITION Z Collect Result_Dam',
#  'HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Dam']

# %%
# 상수 열 삭제
df1_cleaned = df1.drop(columns=constant_columns)
print(df1_cleaned.shape[1])
print(df1.shape[1])
# Out:
# 69
# 77

# %%
def remove_constant_columns(df):
    """
    DataFrame에서 상수 열(모든 값이 동일한 열)을 찾아 삭제하고, 삭제된 열의 이름을 반환합니다.
    
    Parameters:
    df (pd.DataFrame): 상수 열을 삭제할 DataFrame

    Returns:
    tuple: (상수 열이 제거된 DataFrame, 삭제된 상수 열의 리스트)
    """
    # 상수 열 찾기
    constant_columns = [col for col in df.columns if df[col].nunique() == 1]
    
    # 상수 열 출력
    print("삭제된 상수 열:", constant_columns)
    
    # 상수 열 삭제
    df_cleaned = df.drop(columns=constant_columns)
    
    return df_cleaned, constant_columns

# %%
df2_cleaned, constant_columns2 = remove_constant_columns(df2)
df3_cleaned, constant_columns3 = remove_constant_columns(df3)
df4_cleaned, constant_columns4 = remove_constant_columns(df4)
# Out:
# 삭제된 상수 열: ['Process Desc._AutoClave', 'Equipment_AutoClave', 'Insp. Seq No._AutoClave', 'Insp Judge Code_AutoClave', '1st Pressure Judge Value_AutoClave', '2nd Pressure Judge Value_AutoClave', '3rd Pressure Judge Value_AutoClave', 'GMES_ORIGIN_INSP_JUDGE_CODE Collect Result_AutoClave', 'GMES_ORIGIN_INSP_JUDGE_CODE Judge Value_AutoClave']
# 삭제된 상수 열: ['Process Desc._Fill1', 'Insp. Seq No._Fill1', 'Insp Judge Code_Fill1', 'HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Fill1']
# 삭제된 상수 열: ['Process Desc._Fill2', 'Insp. Seq No._Fill2', 'Insp Judge Code_Fill2', 'CURE END POSITION Θ Collect Result_Fill2', 'CURE STANDBY POSITION X Collect Result_Fill2', 'CURE STANDBY POSITION Θ Collect Result_Fill2', 'CURE START POSITION Θ Collect Result_Fill2', 'DISCHARGED SPEED OF RESIN Collect Result_Fill2', 'DISCHARGED TIME OF RESIN(Stage1) Collect Result_Fill2', 'DISCHARGED TIME OF RESIN(Stage2) Collect Result_Fill2', 'DISCHARGED TIME OF RESIN(Stage3) Collect Result_Fill2', 'Dispense Volume(Stage1) Collect Result_Fill2', 'Dispense Volume(Stage2) Collect Result_Fill2', 'Dispense Volume(Stage3) Collect Result_Fill2', 'HEAD NORMAL COORDINATE X AXIS(Stage1) Judge Value_Fill2']

# %%
df

# %% [markdown]
# ### 언더 샘플링

# %% [markdown]
# 데이타 불균형을 해결하기 위해 언더 샘플링을 진행합니다.

# %%
normal_ratio = 1.0  # 1.0 means 1:1 ratio

df_normal = train_data[train_data["target"] == "Normal"]
df_abnormal = train_data[train_data["target"] == "AbNormal"]

num_normal = len(df_normal)
num_abnormal = len(df_abnormal)
print(f"  Total: Normal: {num_normal}, AbNormal: {num_abnormal}")

df_normal = df_normal.sample(n=int(num_abnormal * normal_ratio), replace=False, random_state=RANDOM_STATE)
df_concat = pd.concat([df_normal, df_abnormal], axis=0).reset_index(drop=True)
df_concat.value_counts("target")
# Out:
#   Total: Normal: 38156, AbNormal: 2350
# target
# AbNormal    2350
# Normal      2350
# Name: count, dtype: int64

# %% [markdown]
# ### 데이터 분할

# %%
df_train, df_val = train_test_split(
    df_concat,
    test_size=0.3,
    stratify=df_concat["target"],
    random_state=RANDOM_STATE,
)


def print_stats(df: pd.DataFrame):
    num_normal = len(df[df["target"] == "Normal"])
    num_abnormal = len(df[df["target"] == "AbNormal"])

    print(f"  Total: Normal: {num_normal}, AbNormal: {num_abnormal}" + f" ratio: {num_abnormal/num_normal}")


# Print statistics
print(f"  \tAbnormal\tNormal")
print_stats(df_train)
print_stats(df_val)
# Out:
#   	Abnormal	Normal
#   Total: Normal: 1645, AbNormal: 1645 ratio: 1.0
#   Total: Normal: 705, AbNormal: 705 ratio: 1.0

# %% [markdown]
# ## 3. 모델 학습

# %% [markdown]
# ### 모델 정의

# %%
model = RandomForestClassifier(random_state=RANDOM_STATE)

# %% [markdown]
# ### 모델 학습

# %%
features = []

for col in df_train.columns:
    try:
        df_train[col] = df_train[col].astype(int)
        features.append(col)
    except:
        continue

train_x = df_train[features]
train_y = df_train["target"]

model.fit(train_x, train_y)
# Out:
# RandomForestClassifier(random_state=110)

# %% [markdown]
# ## 4. 제출하기

# %% [markdown]
# ### 테스트 데이터 예측

# %% [markdown]
# 테스트 데이터 불러오기

# %%
test_data = pd.read_csv(os.path.join(ROOT_DIR, "test.csv"))

# %%
df_test_x = test_data[features]

for col in df_test_x.columns:
    try:
        df_test_x.loc[:, col] = df_test_x[col].astype(int)
    except:
        continue

# %%
test_pred = model.predict(df_test_x)
test_pred
# Out:
# array(['AbNormal', 'Normal', 'AbNormal', ..., 'Normal', 'Normal',
#        'AbNormal'], dtype=object)

# %% [markdown]
# ### 제출 파일 작성

# %%
# 제출 데이터 읽어오기 (df_test는 전처리된 데이터가 저장됨)
df_sub = pd.read_csv("submission.csv")
df_sub["target"] = test_pred

# 제출 파일 저장
df_sub.to_csv("submission.csv", index=False)

# %% [markdown]
# **우측 상단의 제출 버튼을 클릭해 결과를 확인하세요**
